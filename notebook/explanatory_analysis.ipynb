# %% [markdown]
# # 1. Introductioning the data

# %% [markdown]
# This notebook contains my basic solution to train a model on a task defined on the dataset shared on [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/datasets) accessible at http://archive.ics.uci.edu/ml/datasets/EMG+data+for+gestures.

# %% [markdown]
# # 2. Dataset

# %% [markdown]
# The dataset contains Electromyography (EMG) recording from the wrist of 36 subjects who were asked to perform one of the 7 predetermined hand gestures. The recording constitutes of 8 channels each corresponding to a sensor. Every subject is asked to perform all of the first 6 gestures while only one subject is also asked to perform the last gesture. The data is structured and saved in CSV-like format. Entries are separated with tab('\t'). The columns are `time`, `channel1` to `channel8`, `class`. The column `class` represents the gesture category. Class zero corresponds to the resting state (no gesture).

# %% [markdown]
# # 3. Loading the data

# %% [markdown]
# Before anything, we need to import a few packages so we can conveniently load, visualize and manipulate the data.

# %%
import os # to walk through the recording files
import pandas as pd # to easily read and manipulate the data
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # another library for visualization


from utils import load_emg_recording

# %% [markdown]
# In the following code segment, we walk through the recording file of each subject and append the content to a pandas DataFrame so everything is stored in a big structured table (`df_all`).

# %%
df_all = None 
# get the list of directories in the EMG dataset
dirname = './data/EMG_data_for_gestures-master'
for filename in os.listdir(dirname):
    file = os.path.join(dirname, filename)
    # 
    for subfilename in os.listdir(file):
        subfile = os.path.join(file, subfilename)
        df = pd.read_csv(subfile, sep='\t')
        df['subject'] = int(filename)
        if df_all is None:
            df_all = df
        else:
            df_all = pd.concat([df_all, df], ignore_index=True)

# %% [markdown]
# Checking the number of samples per class (how imblance data is).

# %%
sns.countplot(x = df_all['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# Checking the missing data

# %%
df_all.isnull().any()
# Out:
# time        False
# channel1    False
# channel2    False
# channel3    False
# channel4    False
# channel5    False
# channel6    False
# channel7    False
# channel8    False
# class        True
# subject     False
# dtype: bool

# %% [markdown]
# Let's see the `NaN` value belongs to which class

# %%
df_all[df_all.isnull().any(axis=1)]
# Out:
#           time  channel1  channel2  channel3  channel4  channel5  channel6  \
# 3985214  97144  -0.00002  -0.00003  -0.00003  -0.00002  -0.00002       0.0
#
#          channel7  channel8  class  subject
# 3985214       0.0  -0.00001    NaN       34

# %%
df_all.loc[3985210:3985218]
# Out:
#           time  channel1  channel2  channel3  channel4  channel5  channel6  \
# 3985210  97140  -0.00002  -0.00003  -0.00003  -0.00002  -0.00002   0.00000
# 3985211  97141  -0.00002  -0.00003  -0.00003  -0.00002  -0.00002   0.00000
# 3985212  97142  -0.00002  -0.00003  -0.00003  -0.00002  -0.00002   0.00000
# 3985213  97143  -0.00002  -0.00003  -0.00003  -0.00002  -0.00002   0.00000
# 3985214  97144  -0.00002  -0.00003  -0.00003  -0.00002  -0.00002   0.00000
# 3985215      1  -0.00001  -0.00002  -0.00003  -0.00001   0.00000   0.00000
# 3985216      3  -0.00001  -0.00002  -0.00003  -0.00001   0.00000   0.00000
# 3985217      4   0.00003   0.00004   0.00005   0.00002  -0.00001  -0.00001
# 3985218      5  -0.00001   0.00000   0.00001  -0.00001  -0.00004  -0.00001
#
#          channel7  channel8  class  subject
# 3985210   0.00000  -0.00001    0.0       34
# 3985211   0.00000  -0.00001    0.0       34
# 3985212   0.00000  -0.00001    0.0       34
# 3985213   0.00000  -0.00001    0.0       34
# 3985214   0.00000  -0.00001    NaN       34
# 3985215  -0.00002   0.00000    0.0       34
# 3985216  -0.00002   0.00000    0.0       34
# 3985217  -0.00002  -0.00002    0.0       34
# 3985218  -0.00002  -0.00002    0.0       34

# %% [markdown]
# The `NaN` value belongs to `calss 0`.

# %% [markdown]
# Visualize the time series corresponding to the subject that we predicted. (example: `Subject 17` )

# %%
# Path to the actual data (example `Subject 17`)
path='data/EMG_data_for_gestures-master/17/2_raw_data_11-20_23.03.16.txt'
df = load_emg_recording(path, True)

# %%
# Path to the predicted data (example `Subject 17`)
df_r = pd.read_csv('res/result.txt')

# %%
def align_yaxis(ax1, ax2):
    """Align zeros of the two axes, zooming them out by same ratio"""
    axes = (ax1, ax2)
    extrema = [ax.get_ylim() for ax in axes]
    tops = [extr[1] / (extr[1] - extr[0]) for extr in extrema]
    # Ensure that plots (intervals) are ordered bottom to top:
    if tops[0] > tops[1]:
        axes, extrema, tops = [list(reversed(l)) for l in (axes, extrema, tops)]

    # How much would the plot overflow if we kept current zoom levels?
    tot_span = tops[1] + 1 - tops[0]

    b_new_t = extrema[0][0] + tot_span * (extrema[0][1] - extrema[0][0])
    t_new_b = extrema[1][1] - tot_span * (extrema[1][1] - extrema[1][0])
    axes[0].set_ylim(extrema[0][0], b_new_t)
    axes[1].set_ylim(t_new_b, extrema[1][1])

# %%
num_channel = 8
for i in range(1, num_channel+1):
    fig = plt.figure(figsize=(12,4))
    ax1 = fig.add_subplot(111)
    ax2 = ax1.twinx() 
    ax1.plot(df.index, df['channel'+str(i)], color='k',label='Channel{}'.format(i))
    ax2.plot(df.index, df['class'], color='orangered',label='Labeled class')
    ax2.plot(df_r.index, df_r['0'], color='royalblue', label='Predicted class', alpha= 0.7)
    align_yaxis(ax1, ax2)
    ax1.legend(loc = 'upper left')
    ax2.legend()
    plt.show()

# %% [markdown]
# # CLI demo

# %% [markdown]
# Locate the root of the project and install the requirements

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.19 in c:\users\marzi\miniconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\marzi\miniconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: click>=1.7 in c:\users\marzi\miniconda3\lib\site-packages (from -r requirements.txt (line 3)) (8.1.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\marzi\miniconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\marzi\miniconda3\lib\site-packages (from -r requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\marzi\miniconda3\lib\site-packages (from pandas>=1.2->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marzi\miniconda3\lib\site-packages (from pandas>=1.2->-r requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: colorama in c:\users\marzi\miniconda3\lib\site-packages (from click>=1.7->-r requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\marzi\miniconda3\lib\site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\marzi\miniconda3\lib\site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\marzi\miniconda3\lib\site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 4)) (1.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\marzi\miniconda3\lib\site-packages (from matplotlib>=3.1.3->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\marzi\miniconda3\lib\site-packages (from matplotlib>=3.1.3->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marzi\miniconda3\lib\site-packages (from matplotlib>=3.1.3->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marzi\miniconda3\lib\site-packages (from matplotlib>=3.1.3->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\marzi\miniconda3\lib\site-packages (from matplotlib>=3.1.3->-r requirements.txt (line 5)) (9.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marzi\miniconda3\lib\site-packages (from matplotlib>=3.1.3->-r requirements.txt (line 5)) (4.33.3)
# Requirement already satisfied: six>=1.5 in c:\users\marzi\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->-r requirements.txt (line 2)) (1.16.0)

# %% [markdown]
# ### print cli usage

# %%
# !python cli.py --help
# Out:
# Usage: cli.py [OPTIONS] COMMAND [ARGS]...
#
#   group definition for click commands.
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   infer-emg  predict gesture class based on the EMG data
#   train-emg  trains a model on data extracted from text files within...

# %% [markdown]
# ### Training
#
# ```bash
# $ python cli.py train-emg -t <path_to_dir_containing_EMG_recordings> -w <window_size> -d <dir_to_save_trained_model> -o <name_of_output_file>
# ```

# %% [markdown]
# Example:

# %%
# !python cli.py train-emg -t .\data\EMG_data_for_gestures-master\01\ -w 100 -d deployed_models -o train_on_01.pkl
# Out:
# ^C

# %% [markdown]
# ### Inference
#
# ```bash
# $ python cli.py infer-emg -r <path_to_dir_containing_EMG_recordings> -m <path_to_dir_containing_trained_model> -o <path_to_save_the_inference_results>
# ```

# %% [markdown]
# Example:

# %%
# !python cli.py infer-emg -r  data/EMG_data_for_gestures-master/17/2_raw_data_11-20_23.03.16.txt -m deployed_models/RandomForestClassifier_w100___2022-06-02.pkl -o inference_output/inference17_2.txt
# Out:
# ^C
